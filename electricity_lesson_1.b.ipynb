# %% [markdown]
# # Wow. A second notebook. Full of buzzy words and fizzled out topics.
# ## Moving ON.
#
#
# #### So my prodigal reader, if you're thinking..this is a lot.

# %%
if 'a' == 'a':
    if 1 == 1:
        if True != False:
            if 2 > 1:
                if 3 <= 3:
                    if 'b' != 'c':
                        if 4.0 == 4.0:
                            if [1,2] == [1,2]:
                                if (3,4) != (5,6):
                                    if {7:8} == {7:8}:
                                        if None is None:
                                            if set([9,10]) == set([9,10]):
                                                if not False:
                                                    if abs(-11) == 11:
                                                        if round(12.0) == 12:
                                                            print("You're telling me!")
# Out:
# You're telling me!

# %%
# Defining a variable
a = 'a'

# Checking if two strings are equal
if a == 'a':
    # Defining an integer
    x = 1

    # Comparing two integers
    if x == 1:
        # Using a built-in function - len()
        c = len('Hello')

        # Comparing two integers
        if c == 5:
            # Defining a list
            d = [2, 4, 6]

            # Checking if one number is greater than another
            if d[0] > 1:
                # Adding an element to the list using append()
                d.append(8)

                # Checking if one number is less than or equal to another
                if len(d) <= 4:
                    # Defining a dictionary
                    e = {'b': 2, 'c': 3}

                    # Checking if two strings are not equal
                    if e['b'] != 'c':
                        # Updating a value in the dictionary
                        e['b'] = 20

                        # Comparing an integer and a dictionary value
                        if e['b'] == 20:
                            # Defining a tuple
                            f = (1, 2)

                            # Comparing two tuples
                            if f != (3, 4):
                                # Defining a set
                                g = {7, 8, 9}

                                # Comparing two sets
                                if g == {7, 8, 9}:
                                    # Using the 'not' operator to reverse a boolean
                                    if not False:
                                        # Using the abs() function to get the absolute value of a number
                                        if abs(-11) == 11:
                                            # Using the round() function to round a float to the nearest integer
                                            if round(12.0) == 12:
                                                # Printing a string to the console
                                                print("You're telling me!")
                                                print("But wait, there's more!")

                                                # Creating a for loop that iterates over a range of numbers
                                                for i in range(5):
                                                    print(f"Iteration {i}: The endless cycle continues...soon(tm)")

                                                # Creating a list using list comprehension
                                                squares = [y ** 2 for y in range(40)]
                                                print(f"List comprehension: Because why write quantities(four lines) of code when one will do? Here are some paralellograms: {squares}")

                                                # Creating a function that adds two numbers together 
                                                def add_numbers(y, z):
                                                    return y + z

                                                result = int(add_numbers(e['b'], 2))
                                                print(f"The result is {result+20}. Yeah, we can even add numbers. We're basically wumbo wizards, if you made it this far and haven't started planking.")
# Out:
# You're telling me!
# But wait, there's more!
# Iteration 0: The endless cycle continues...soon(tm)
# Iteration 1: The endless cycle continues...soon(tm)
# Iteration 2: The endless cycle continues...soon(tm)
# Iteration 3: The endless cycle continues...soon(tm)
# Iteration 4: The endless cycle continues...soon(tm)
# List comprehension: Because why write quantities(four lines) of code when one will do? Here are some paralellograms: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521]
# The result is 42. Yeah, we can even add numbers. We're basically wumbo wizards, if you made it this far and haven't started planking.

# %% [markdown]
# Now we can get started. What're we doing? Oh right! Pandas AI.

# %% [markdown]
# So we have our electricity CSV 👍 downloaded from our resource url. Great!
# Now let's get our directory set again if you haven't already/or are coming back to this lesson after a break (if you haven't taken a break, well, that's your right reserved).

# %%
import os
working_directory = os.getcwd()
print(working_directory)
# Out:
# C:\Users\Taylor\AppData\Local\Programs\Microsoft VS Code Insiders

# %% [markdown]
# My `cwd` is reset you'll see. ^<br>
# I've copied the exact block we utilized in lesson 1.a for this below. v

# %%
working_directory="C:\\Users\\Taylor\\Documents" # We set the working directory VARIABLE to the User's Documents folder
os.chdir(working_directory)                      # We change the working directory to the User's Documents folder WITH the os.chdir() FUNCTION
print(working_directory)
# Out:
# C:\Users\Taylor\Documents

# %% [markdown]
# That's not quite what we want since we went to another nested folder at this location. Let's do that.

# %%
folder_name = "electricity_data"    
root_directory ="C:\\Users\\Taylor\\Documents"      
print(root_directory)
working_directory = os.path.join(root_directory, folder_name)
os.chdir(working_directory)
print(os.getcwd())

#This might look familiar from the previous lesson, but we don't see most of the comments that make it easier to read.
# Out:
# C:\Users\Taylor\Documents
# C:\Users\Taylor\Documents\electricity_data

# %% [markdown]
# Something, about a bear and a fish in the sky.<br>
# Oh brother, you might say!<br>
#
# It's just time for PandasAI!

# %% [markdown]
# It's this simple.
# Import Pandas

# %%
# !pip install pandas
# !pip install pandasai
# Out:
# ...
#      -------------------------------------- 42.8/42.8 kB 346.1 kB/s eta 0:00:00
# ...
#   Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autofaiss 2.9.3 requires fsspec==2021.11.0, but you have fsspec 2023.6.0 which is incompatible.
# clip-retrieval 2.24.2 requires fsspec==2021.11.0, but you have fsspec 2023.6.0 which is incompatible.
# streamlit 1.24.0 requires pillow<10,>=6.2.0, but you have pillow 10.0.0 which is incompatible.
# streamlit 1.24.0 requires tzlocal<5,>=1.1, but you have tzlocal 5.0.1 which is incompatible.

# %%
import pandas as pd #this is how we usually import pandas
from pandasai import PandasAI as pdai #this is how we import pandasai, don't break the chain
from pandasai.llm.openai import OpenAI #For Simplicity, we will utilize ChatGPT through the OpenAI API, Leaving a ##todo: implement local miniture model

# %% [markdown]
# IMPORTS COMPLETE 🫡

# %%
# This key is for the OpenAI API. It is a secret key, so don't share it with anyone. Also, don't upload it to GitHub. 
your_api_token_variable = "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" #get your api token from https://beta.openai.com/account/api-keys
pandas_ai=OpenAI(api_token=your_api_token_variable)

# %% [markdown]
# COUNTING DOWN....

# %%
working_df=pd.read_csv(f"{working_directory +'/electricity.csv'}")
print(working_df)
#there's the data!
# Out:
#       Utility.Number  ... Retail.Total.Customers
# 0                 34  ...                 3844.0
# 1                 55  ...                 3229.0
# 2                 59  ...                 5494.0
# 3                 84  ...                35934.0
# 4                 87  ...                 1185.0
# ...              ...  ...                    ...
# 3169           63169  ...                  329.0
# 3170           63232  ...                14982.0
# 3171           63364  ...                  877.0
# 3172           63367  ...                  134.0
# 3173           63546  ...                 7848.0
#
# [3174 rows x 38 columns]

# %%
pandas_ai=pdai(llm=pandas_ai) #Don't get tripped out by this. 
            #We are just letting the ai variable become the output of the PandasAI(MODEL) function.
            
pandas_ai(working_df, prompt="What company, has the most sales by dollar amount?")
# Out:
# 'Constellation NewEnergy, Inc'

# %% [markdown]
# Amazing. Actually paralyzingly fascinating. So don't get stuck here long. We're in this one together.

# %% [markdown]
# Next let's find some more meaningful ways to represent the information within the CSV! It's all in that CSV.

# %%
pandas_ai(
    working_df,
    "Plot the data in a scatter plot of the Summer and Winter peaks."
)

# %% [markdown]
# Now, that's beauty 🤌
# 🔢 🧠<br><br><br><br><br>BUT Wait, THERE'S MORE! 🪃
# Clean your data!

# %%
pandas_ai.clean_data(working_df)
# Out:
#       Utility.Number  ... Retail.Total.Customers
# 0                 34  ...                 3844.0
# 1                 55  ...                 3229.0
# 2                 59  ...                 5494.0
# 3                 84  ...                35934.0
# 4                 87  ...                 1185.0
# ...              ...  ...                    ...
# 3169           63169  ...                  329.0
# 3170           63232  ...                14982.0
# 3171           63364  ...                  877.0
# 3172           63367  ...                  134.0
# 3173           63546  ...                 7848.0
#
# [3174 rows x 38 columns]

# %% [markdown]
# That's not all, you say??

# %%
cache_frame=working_df # Let's set that there.
pandas_ai.generate_features(working_df) # Generate features?? What does that mean? Like, add columns?
# Out:
#       Utility.Number  ... Total.Retail.Customers
# 0                 34  ...                 3844.0
# 1                 55  ...                 3229.0
# 2                 59  ...                 5494.0
# 3                 84  ...                35934.0
# 4                 87  ...                 1185.0
# ...              ...  ...                    ...
# 3169           63169  ...                  329.0
# 3170           63232  ...                14982.0
# 3171           63364  ...                  877.0
# 3172           63367  ...                  134.0
# 3173           63546  ...                 7848.0
#
# [3174 rows x 45 columns]

# %% [markdown]
# It did add columns!
# ###### are you reading the comments?

# %%
import time
pandas_ai.plot_correlation_heatmap(cache_frame)
# Out:
# <string>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# Ahh, yes, beautiful, meaningful, data. More like an inkblob, at this pass.
# <br> *force* 😄

# %% [markdown]
# ## So now, we've succesfully, downloaded our `csv`.
# ## Saved our file, on to the hard drive.
# ## Then we loaded up our Pandas assortium.
# ## Allowing for our data to be prompted like the wizards we know we are, kinda!
